# %% [markdown]
# ### Drawing Craters

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt

from saturation.simulation import *
from saturation.distributions import *
from saturation.geometry import *
from saturation.plotting import *

# %%
scale = 1000
dist = ParetoProbabilityDistribution(cdf_slope=2.8, x_min=8, x_max=500)
craters = get_craters(500, dist, scale)

# %%
fig, ax = plt.subplots(figsize=(8, 8))

ax.set_xlim([0, scale])
ax.set_ylim([0, scale])

for crater in craters.itertuples():
    plot_circle((crater.x, crater.y), crater.radius, ax)
    
plt.show()
